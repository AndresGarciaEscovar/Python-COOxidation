# %% [markdown]
# # Carbon Monoxide Oxidation on Ruthenium (111) Equations

# %% [markdown]
# ## Considerations

# %% [markdown]
# The goal is to write down the differential equations for the exact model of carbon monoxide oxidation on Ruthenium (111) surface, that consists of three (3) adjacent sites:
# <a id='systemModelPicture'></a>
#
# <table {style="border-style: solid; width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# <table>
#
# where different process can take place. In this model, the three sites can take **one** of three states at a time, i.e., statistically independent states:
#
# -  The site is empty, i.e., there are no atoms, labeled as $E$.
# -  The site has a carbon monoxide atom, labeled as $CO$.
# -  The site has an oxygen atom $O$.
#
# Thus, at a particular moment, the sites could have a state given by, for example:
# <table {style="border-style: solid; width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#     </tr>
# <table>
#
# The probability of finding the sites in the above state will be denoted as $P(E,CO,O)$. In general, the probability of finding site $1$ in state $X$, site $2$ in state $Y$ and site $3$ in state $Z$, where $X,Y,Z\in\{E,O,CO\}$, will be denoted by $P(X,Y,Z)$, or equivalently $\left<X_{1}, Y_{2}, Z_{3}\right>$:
#
# $$\begin{align}
#       P(X,Y,Z) \equiv \left<X_{1}Y_{2}Z_{3}\right>
#   \end{align}
# $$
#
# Notice that using the latter notation is better, since the sites are identified by the subindex and notation like $\left<X_{1}Y_{2}Z_{3}\right>\equiv\left<X_{2}Y_{1}Z_{3}\right>$ can be used, (**ONLY**) when needed. We shall be using the identity:
# <a id='probIdentity'></a>
#
# $$
#     \begin{align}
#         1 = & \left<E_{i}\right>+\left<O_{i}\right>+\left<CO_{i}\right>\\
#         1 = & \sum_{X\in S}\left<X_{i}\right>,\qquad\qquad\qquad i\in\left\{1,2,3\right\},\quad  S=\left\{E,O,CO\right\}
#     \end{align}
# $$
# As well as the completeness relations:
# $$
#     \begin{align}
#         \left<X_{i}\right> = \sum_{Y\in S}\left<X_{i}Y_{j}\right>,\qquad i,j\in\left\{1,2,3\right\},\quad i\neq j,\quad  S=\left\{E,O,CO\right\},\quad  X\in\left\{E,O,CO\right\}\\
#     \left<X_{i}Y_{j}\right> = \sum_{Z\in S}\left<X_{i}Y_{j}Z_{k}\right>,\qquad i,j,k\in\left\{1,2,3\right\},\quad i\neq j,\quad j\neq k,\quad i\neq k,\quad  S=\left\{E,O,CO\right\},\quad  X, Y\in\left\{E,O,CO\right\}
#     \end{align}
# $$
#
# The total number of states can be easily calculated:
#
# -   Site $1$ can take $3$ states, that are independent from those of site $2$ and site $3$.
# -   Site $2$ can take $3$ states, that are independent from those of site $1$ and site $3$.
# -   Site $3$ can take $3$ states, that are independent from those of site $1$ and site $2$.
#
# Thus, for the three-site probability function $P(X,Y,Z)$, the number of states is $3\times3\times3 = 3^{3}=27$. We can, thus, generate a table with the probabilities we seek.

# %%
# Imports: import
import pandas as pd

# Imports: from.
from itertools import product
from IPython.display import display, Markdown, Latex

# The states the sites can take.
state_list = ["E", "O", "CO"]

# List of possible states for triplets
triplets_states = [[i, j, k] for i, j, k in product(state_list, state_list, state_list)]

# Define a data frame.
df = pd.DataFrame(triplets_states, columns=['Site 1', 'Site 2', 'Site 3'])
df.index = range(1, len(df) + 1)

# %% [markdown]
# The following is the generated table with the possible states:
# <a id='tripletQuantities'></a>
# {{df}}
# As it can  be seen, there are a total of $27$ states.

# %% [markdown]
# ## Processes in the system.

# %% [markdown]
# For the system to transition into different states, the following processes can take place:

# %% [markdown]
# 1. <u>Dissociative oxygen adsorption:</u> For this, the system must have at least two adjacent empty sites.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
#
#    where $X\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{O_{ads}}$.

# %% [markdown]
# 2. <u>Associative oxygen desorption:</u> For this, the system must have at least two adjacent sites containing oxygen.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
#
#    where $X\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{O_{des}}$.

# %% [markdown]
# 3. <u>Oxygen diffusion:</u> For this, the system must have a site with oxygen and an adjacent empty site.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
#
#    where $X\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{O_{dif}}$.

# %% [markdown]
# 4. <u>Carbon monoxide adsorption:</u> For this, the system must have at least an empty site.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#     </tr>
# </table>
#
#    where $X,Y\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{CO_{ads}}$.

# %% [markdown]
# 5. <u>Carbon monoxide desorption:</u> For this, the system must have at least a site with carbon monoxide.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
#
#    where $X,Y\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{CO_{des}}$.

# %% [markdown]
# 6. <u>Carbon monoxide diffusion:</u> For this, the system must have at least a site with carbon monoxide with an adjacent empty site.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
#
#    where $X\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{CO_{dif}}$.

# %% [markdown]
# 7. <u>Carbon monoxide-oxygen in-lattice adjacent pair reaction (Langmuir-Hinshelwood reaction):</u> For this, the system must have a carbon monoxide-oxygen neighboring pair. When the reaction occurs, both particles immediately desorb.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
#
#    where $X\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{COO_{apr}}$.

# %% [markdown]
# 8. <u>Oxygen gas-phase reaction (Elay-Rideal reaction):</u> For this, the system must have a site with oxygen. The oxygen on the surface will react with the gaseous carbon monoxide and immediately desorb.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$Y$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
#
#    where $X,Y\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{COO_{gas}}$.

# %% [markdown]
# 9. <u>Carbon monoxide-oxygen in-lattice random pair reaction:</u> For this, the system must have at least a carbon monoxide-oxygen neighboring pair. When the reaction occurs, both particles immediately desorb.
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
# <table {style="width: 50%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$X$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
#
# In the particular cases where there are two oxygen atoms, that are contemplated above, the desorption processes are given by:
# <table {style="width: 70%; text-align: center;"}>
#     <tr>
#         <td colspan="3" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>Before</u></td>
#         <td style="background-color: white; border-style: solid; border-color: white;"></td>
#         <td  colspan="7" style="background-color: white; border-style: solid; border-color: white; text-align: center;"><u>After</u></td>
#     </tr>
#     <tr>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $1$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $2$</td>
#         <td {style="background-color: white; border-style: solid; border-color: white; width: 50%; text-align: center;"}>Site $3$</td>
#     </tr>
# </table>
# <table {style="width: 70%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}>or</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#     </tr>
# </table>
# <table {style="width: 70%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}>or</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#     </tr>
# </table>
# <table {style="width: 70%; text-align: center;"}>
#     <tr>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$CO$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}></td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="background-color: white; width: 50%; text-align: center;"}>or</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$O$</td>
#         <td {style="border-style: solid; width: 50%; text-align: center;"}>$E$</td>
#     </tr>
# </table>
#
#    where $X\in\left\{E, O, CO\right\}$. This process happens at a rate $k_{COO_{rnd}}$. We will use the convention:
#
#    $$
#    \boxed{k_{COO_{rnd}}=0}
# $$

# %% [markdown]
# ## The exact master equations

# %% [markdown]
# ### The master equations

# %% [markdown]
# The master equation dictates that, for stochastic process, the simplest way to write the down the evolution equations of a system is a system of (potentially coupled) first order linear differential equations, is:
#
# $$
# \begin{align}
#    \frac{dP(x)}{dt} = \int_{-\infty}^{\infty}\left(W(x',x)P(x') - W(x,x')P(x)\right) dx',\qquad P(x)\equiv P(x,t);
# \end{align}
# $$
#
# where $W(x',x)$ is the "propagator", that indicates the weight density of transition (a dimensionless quantity per unit time per unit of measure) from the state $x'$ to the state $x$, where $dx'$ is a proper measure related to the definition of the probability space of a set of continuous, and statistically independent, random variables $x$. The probabilities must __always__ satisfy the identities:
#
# $$
#    \begin{align}
#         0\leq P(x,t) \leq 1,\qquad \int_{-\infty}^{\infty}P(x,t)\,dx = 1.
#    \end{align}
# $$
#
# In the case of a discrete, and finite dimensional, space the master equations can be re-written as:
#
# $$
# \begin{align}
#    \frac{dP(x_{i})}{dt} = \sum_{j}\left(W_{ji}P(x_{j}) - W_{ij}P(x_{i})\right),\qquad P(x_{i})\equiv P(x_{i},t),\qquad x_{i}\in S;
# \end{align}
# $$
#
# where, in this case, $W_{ij}$ represents the transition rate from state $i$ to state $j$ and $S=\left\{x_{1},\ldots,x_{N}\right\}$ is the set of ALL possible states of the system. The probabilities must __always__ satisfy the identities:
#
# $$
#    \begin{align}
#         0\leq P(x,t) \leq 1\quad\forall\, x\in S,\qquad \sum_{x\in S}P(x,t) = 1.
#    \end{align}
# $$

# %% [markdown]
# ### The hierarchical master equations

# %% [markdown]
# For this discussion, we shall consider discrete and finite systems.
#
# For stochastic systems, the quantities we are usually interested in are single-state probabilities, i.e., $P(x_{i})$, where $x_{i}$ represents a state from the set of all <i>univariate statistically independent</i> variables. Since the sum of all the probabilities must satisfy the [probability identity](#probIdentity), we denote the set of all <i>univariate statistically independent</i> variables as the __first order__ variables.
#
# In our case, we have three sets of univariate statistically independent variables:
# <table style="width: 70%; background-color: white;">
#     <tr>
#         <td style="width: 50%; background-color: white; text-align: left;">
#             <ul>
#             <li>
#                 $S_{1}=\left\{E_{1},O_{1},CO_{1}\right\}$.
#             </li>
#             </ul>
#         </td>
#         <td style="width: 50%; background-color: white; text-align: left;">
#             <ul>
#             <li>
#                 $S_{2}=\left\{E_{2},O_{2},CO_{2}\right\}$.
#             </li>
#             </ul>
#         </td>
#         <td style="width: 50%; background-color: white; text-align: left;">
#             <ul>
#             <li>
#                 $S_{3}=\left\{E_{3},O_{3},CO_{3}\right\}$.
#             </li>
#             </ul>
#         </td>
#     </tr>
# <table>
# Where $S_{i}$, $i\in\left\{1,2,3\right\}$, are the statistically independent variables for the $i^{\text{th}}$ site. Thus, the <i>hierarchical master equations</i> refers to the order to which the terms in the time derivative are written. Thus, in this model, for example, the master equations in the <b>lowest hierarchical order</b>, or first order, would be written as:
#
# $$
#     \begin{align}
#         \frac{d\left<E_{1}\right>}{dt}=&\ldots,&\qquad
#         \frac{d\left<O_{1}\right>}{dt}=&\ldots,&\qquad
#         \frac{d\left<CO_{1}\right>}{dt}=&\ldots,\\
#         \mbox{}\\
#         \frac{d\left<E_{2}\right>}{dt}=&\ldots,&\qquad
#         \frac{d\left<O_{2}\right>}{dt}=&\ldots,&\qquad
#         \frac{d\left<CO_{2}\right>}{dt}=&\ldots,\\
#         \mbox{}\\
#         \frac{d\left<E_{3}\right>}{dt}=&\ldots,&\qquad
#         \frac{d\left<O_{3}\right>}{dt}=&\ldots,&\qquad
#         \frac{d\left<CO_{3}\right>}{dt}=&\ldots\,
#         .\\
#     \end{align}
# $$
#
# The second order equations, for example, would involve the bi-variate probability of different sites:
#
# $$
#     \begin{align}
#         \frac{d\left<X_{i}Y_{j}\right>}{dt}=&\ldots,\qquad X,Y\in\left\{E,O,CO\right\},\qquad i,j\in\left\{1,2,3\right\},\qquad i\neq j.
#     \end{align}
# $$
#
# Thus, the $n^{\text{th}}$ order equations in the hierarchy would be:
#
# $$
#     \begin{align}
#         \frac{d\left<X_{i_{1}}\ldots X_{i_{N}}\right>}{dt}=&\ldots,\qquad X_{i_{1}},\ldots X_{i_{N}}\in\left\{E,O,CO\right\},\qquad i_{1},\ldots,i_{N}\in\left\{1,\ldots,N\right\},\qquad i_{k}\neq i_{l},\qquad\forall \,k,l\in\left\{1,\ldots,N\right\},\qquad k\neq l.
#     \end{align}
# $$

# %% [markdown]
# ### Lowest order hierarchical equations

# %% [markdown]
# We shall consider the [three-site model](#systemModelPicture), such that there are a total of nine (9) independent states.
# <table style="width: 40%; background-color: white;">
#     <tr>
#         <td colspan="3" style="width: 50%; background-color: white; text-align: center;">
#             <u>Possible States</u>
#         </td>
#     </tr>
#     <tr>
#         <th style="width: 50%; background-color: white; text-align: center;">
#             Site $1$
#         </th>
#         <th style="width: 50%; background-color: white; text-align: center;">
#             Site $2$
#         </th>
#         <th style="width: 50%; background-color: white; text-align: center;">
#             Site $3$
#         </th>
#     </tr>
#     <tr>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $E$
#         </td>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $E$
#         </td>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $E$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $O$
#         </td>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $O$
#         </td>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $O$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $CO$
#         </td>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $CO$
#         </td>
#         <td style="width: 50%; background-color: white; text-align: center;">
#             $CO$
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### Equations for site 1

# %% [markdown]
# $\frac{d\left<E_{1}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{1}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{1}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{1}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<E_{1}\right>}{dt}=& - k_{O_{ads}}\left<E_{1}E_{2}\right>
#                                  %
#                                  + k_{O_{des}}\left<O_{1}O_{2}\right>
#                                  %
#                                  + k_{O_{dif}}\left(
#                                         \left<O_{1}E_{2}\right>
#                                       - \left<E_{1}O_{2}\right>
#                                    \right)
#                                  %%%%%%%
#                                  - k_{CO_{ads}}\left<E_{1}\right>
#                                  %
#                                  + k_{CO_{des}}\left<CO_{1}\right>\\
#                                  %
#                                 &+ k_{CO_{dif}}\left(
#                                         \left<CO_{1}E_{2}\right>
#                                       - \left<E_{1}CO_{2}\right>
#                                    \right)
#                                  %%%%%%%
#                                  + k_{COO_{apr}}
#                                  \left(
#                                      \left<CO_{1}O_{2}\right> +
#                                      \left<O_{1}CO_{2}\right>
#                                  \right)
#                                  %
#                                  + k_{COO_{gas}}\left<O_{1}\right>
# \end{align}
# $$

# %% [markdown]
# $\frac{d\left<O_{1}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=1 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{1}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=1 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<O_{1}\right>}{dt}=&  k_{O_{ads}}\left<E_{1}E_{2}\right>
#                                  %
#                                  - k_{O_{des}}\left<O_{1}O_{2}\right>
#                                  %
#                                  + k_{O_{dif}}\left(
#                                         \left<E_{1}O_{2}\right>
#                                       - \left<O_{1}E_{2}\right>
#                                    \right)
#                                  %%%%%%
#                                  - k_{COO_{apr}}\left<O_{1}CO_{2}\right>
#                                  %
#                                  - k_{COO_{gas}}\left<O_{1}\right>
# \end{align}
# $$

# %% [markdown]
# $\frac{d\left<CO_{1}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{1}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{1}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<CO_{1}\right>}{dt}=& k_{CO_{ads}}\left<E_{1}\right>
#                                   %
#                                   - k_{CO_{des}}\left<CO_{1}\right>
#                                   %
#                                   + k_{CO_{dif}}\left(
#                                         \left<E_{1}CO_{2}\right>
#                                       - \left<CO_{1}E_{2}\right>
#                                    \right)
#                                   %
#                                   - k_{COO_{apr}}\left<CO_{1}O_{2}\right>
# \end{align}
# $$

# %% [markdown]
# Notice that $\frac{\left<E_{1}\right>}{dt} = -\frac{\left<O_{1}\right>}{dt} - \frac{\left<CO_{1}\right>}{dt}$, that clearly implies $\frac{d\left<E_{1}\right>}{dt} + \frac{d\left<O_{1}\right>}{dt} + \frac{d\left<CO_{1}\right>}{dt}=0\,\rightarrow\, \left<E_{1}\right> + \left<CO_{1}\right> + \left<O_{1}\right> = \underbrace{\text{constant}}_{1}$, as it should be.

# %% [markdown]
# #### Equations for site 2

# %% [markdown]
# $\frac{d\left<E_{2}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=4 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<E_{2}\right>}{dt}=& -k_{O_{ads}}\left(
#                                       \left<E_{1}E_{2}\right>
#                                     + \left<E_{2}E_{3}\right>
#                                 \right)
#                                 %
#                                 + k_{O_{des}}\left(
#                                       \left<O_{1}O_{2}\right>
#                                     + \left<O_{2}O_{3}\right>
#                                 \right)
#                                 %
#                                 + k_{O_{dif}}
#                                 \left(
#                                       \left<E_{1}O_{2}\right>
#                                     + \left<O_{2}E_{3}\right>
#                                     - \left<O_{1}E_{2}\right>
#                                     - \left<E_{2}O_{3}\right>
#                                 \right)\\
#                                 %%%%%
#                                &- k_{CO_{ads}}\left<E_{2}\right>
#                                 %
#                                 + k_{CO_{des}}\left<CO_{2}\right>
#                                 %
#                                 + k_{CO_{dif}}
#                                 \left(
#                                       \left<E_{1}CO_{2}\right>
#                                     + \left<CO_{2}E_{3}\right>
#                                     - \left<CO_{1}E_{2}\right>
#                                     - \left<E_{2}CO_{3}\right>
#                                 \right)\\
#                                 %%%%%
#                                &+ k_{COO_{apr}}
#                                \left(
#                                       \left<O_{1}CO_{2}\right>
#                                     + \left<CO_{2}O_{3}\right>
#                                     + \left<CO_{1}O_{2}\right>
#                                     + \left<O_{2}CO_{3}\right>
#                                 \right)
#                                 + k_{COO_{gas}}\left<O_{2}\right>
# \end{align}
# $$

# %% [markdown]
# $\frac{d\left<O_{2}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=4 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{1}O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<O_{2}\right>}{dt}=&
#                                  k_{O_{ads}}\left(
#                                       \left<E_{1}E_{2}\right>
#                                     + \left<E_{2}E_{3}\right>
#                                 \right)
#                                %
#                                - k_{O_{des}}\left(
#                                       \left<O_{1}O_{2}\right>
#                                     + \left<O_{2}O_{3}\right>
#                                 \right)
#                                %
#                                + k_{O_{dif}}\left(
#                                       \left<O_{1}E_{2}\right>
#                                     + \left<E_{2}O_{3}\right>
#                                     - \left<E_{1}O_{2}\right>
#                                     - \left<O_{2}E_{3}\right>
#                                 \right)\\
#                                %%%%%
#                               &- k_{COO_{apr}}\left(
#                                       \left<CO_{1}O_{2}\right>
#                                     + \left<O_{2}CO_{3}\right>
#                                 \right)
#                                %
#                                - k_{COO_{gas}}\left<O_{2}\right>
# \end{align}
# $$

# %% [markdown]
# $\frac{d\left<CO_{2}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=4 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{1}E_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{1}CO_{2}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<CO_{2}\right>}{dt}=&
#                                 + k_{CO_{ads}}\left<E_{2}\right>
#                                 %
#                                 - k_{CO_{des}}\left<CO_{2}\right>
#                                 %
#                                 + k_{CO_{dif}}\left(
#                                       \left<CO_{1}E_{2}\right>
#                                     + \left<E_{2}CO_{3}\right>
#                                     - \left<E_{1}CO_{2}\right>
#                                     - \left<CO_{2}E_{3}\right>
#                                 \right)\\
#                                 %%%%%%
#                                &- k_{COO_{apr}}\left(
#                                       \left<O_{1}CO_{2}\right>
#                                     + \left<CO_{2}O_{3}\right>
#                                 \right)
# \end{align}
# $$

# %% [markdown]
# Notice that $\frac{\left<E_{2}\right>}{dt} = -\frac{\left<O_{2}\right>}{dt} - \frac{\left<CO_{2}\right>}{dt}$, that clearly implies $\frac{d\left<E_{2}\right>}{dt} + \frac{d\left<O_{2}\right>}{dt} + \frac{d\left<CO_{2}\right>}{dt}=0\,\rightarrow\, \left<E_{2}\right> + \left<CO_{2}\right> + \left<O_{2}\right> = \underbrace{\text{constant}}_{1}$, as it should be.

# %% [markdown]
# #### Equations for site 3

# %% [markdown]
# $\frac{d\left<E_{3}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<E_{3}\right>}{dt}=&
#                                  - k_{O_{ads}}\left<E_{2}E_{3}\right>
#                                  %
#                                  + k_{O_{des}}\left<O_{2}O_{3}\right>
#                                  %
#                                  - k_{O_{dif}}\left(
#                                       \left<O_{2}E_{3}\right>
#                                     - \left<E_{2}O_{3}\right>
#                                 \right)
#                                  %%%%%%
#                                  - k_{CO_{ads}}\left<E_{3}\right>
#                                  %
#                                  + k_{CO_{des}}\left<CO_{3}\right>\\
#                                  %
#                                 &- k_{CO_{dif}}\left(
#                                       \left<CO_{2}E_{3}\right>
#                                     - \left<E_{2}CO_{3}\right>
#                                 \right)
#                                  %%%%%
#                                  + k_{COO_{apr}}\left(
#                                       \left<CO_{2}O_{3}\right>
#                                     + \left<O_{2}CO_{3}\right>
#                                 \right)
#                                  %
#                                  + k_{COO_{gas}}\left<O_{3}\right>
# \end{align}
# $$

# %% [markdown]
# $\frac{d\left<O_{3}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<O_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{2}O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<O_{3}\right>}{dt}=&
#                                  k_{O_{ads}}\left<E_{2}E_{3}\right>
#                                %
#                                - k_{O_{des}}\left<O_{2}O_{3}\right>
#                                %
#                                + k_{O_{dif}}\left(
#                                       \left<O_{2}E_{3}\right>
#                                     - \left<E_{2}O_{3}\right>
#                                 \right)
#                                %%%%%%
#                                - k_{COO_{apr}}\left<CO_{2}O_{3}\right>
#                                %
#                                - k_{COO_{gas}}\left<O_{3}\right>
# \end{align}
# $$

# %% [markdown]
# $\frac{d\left<E_{3}\right>}{dt}$:
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;"> Contribution
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $1$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $2$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             site $3$
#         </td>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white;  width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $O$ diffusion</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ adsorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ desorption</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<E_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$ diffusion</td>
#     </tr>
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $+\left<CO_{2}E_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $E$
#         </td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#             $-\left<O_{2}CO_{3}\right>$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $O$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $CO$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ pair reaction
#             (Langmuir-Hinshelwood)</td>
#     </tr>
# </table>
# <!--Blank line -->
# <table style="width: 70%; background-color: white; text-align: center;">
#     <tr>
#         <td style="width: 70%; background-color: white; text-align: center;">
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td style="border-style: solid; background-color: white; width: 70%; text-align: center;">
#             $-$
#         </td>
#         <td rowspan=2 style="background-color: white;  width: 70%; text-align: center;"> $CO$-$O$ gas-phase
#             reaction (Elay-Rideal)</td>
#     </tr>
# </table>
#
# ***
#
# $$
# \begin{align}
# \frac{d\left<CO_{3}\right>}{dt}=&
#                                 + k_{CO_{ads}} \left<E_{3}\right>
#                                 %
#                                 - k_{CO_{des}} \left<CO_{3}\right>
#                                 %
#                                 + k_{CO_{dif}}\left(
#                                       \left<CO_{2}E_{3}\right>
#                                     - \left<E_{2}CO_{3}\right>
#                                 \right)
#                                 %%%%%%%
#                                 - k_{COO_{apr}}\left<O_{2}CO_{3}\right>
# \end{align}
# $$

# %% [markdown]
# Notice that $\frac{\left<E_{3}\right>}{dt} = -\frac{\left<O_{3}\right>}{dt} - \frac{\left<CO_{3}\right>}{dt}$, that clearly implies $\frac{d\left<E_{3}\right>}{dt} + \frac{d\left<O_{3}\right>}{dt} + \frac{d\left<CO_{3}\right>}{dt}=0\,\rightarrow\, \left<E_{3}\right> + \left<CO_{3}\right> + \left<O_{3}\right> = \underbrace{\text{constant}}_{1}$, as it should be.

# %% [markdown]
# ### Exact triplet equations

# %% [markdown]
# We had already found the [possible states](#tripletQuantities) the system can be in. For simplicity, we can label the states as:
# <table style="background-color: white; width: 100%; text-align: left;">
#     <tr>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             1. $\left<CO_{1}CO_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             2. $\left<CO_{1}CO_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             3. $\left<CO_{1}CO_{2}E_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             4. $\left<CO_{1}O_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             5. $\left<CO_{1}O_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             6. $\left<CO_{1}O_{2}E_{3}\right>$
#         </td>
#      </tr>
#      <tr>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             7. $\left<CO_{1}E_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             8. $\left<CO_{1}E_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             9. $\left<CO_{1}E_{2}E_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             10. $\left<O_{1}CO_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             11. $\left<O_{1}CO_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             12. $\left<O_{1}CO_{2}E_{3}\right>$
#         </td>
#     </tr>
#     <tr>
#          <td style="background-color: white; width: 100%; text-align: left;">
#             13. $\left<O_{1}O_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             14. $\left<O_{1}O_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             15. $\left<O_{1}O_{2}E_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             16. $\left<O_{1}E_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             17. $\left<O_{1}E_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             18. $\left<O_{1}E_{2}E_{3}\right>$
#         </td>
#     </tr>
#     <tr>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             19. $\left<E_{1}CO_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             20. $\left<E_{1}CO_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             21. $\left<E_{1}CO_{2}E_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             22. $\left<E_{1}O_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             23. $\left<E_{1}O_{2}O_{3}\right>$
#         </td>
#     </tr>
#     <tr>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             24. $\left<E_{1}O_{2}E_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             25. $\left<E_{1}E_{2}CO_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             26. $\left<E_{1}E_{2}O_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#             27. $\left<E_{1}E_{2}E_{3}\right>$
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#         </td>
#         <td style="background-color: white; width: 100%; text-align: left;">
#         </td>
#     </tr>
# </table>
#
# To obtain the master equations, for each entry in the table, we can make a table with the corresponding coefficients that precede each term and then write the equation.

# %% [markdown]
# 1. $\frac{d\left<CO_{1}CO_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $-3k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}CO_{2}CO_{3}\right>}{dt}=&-3k_{CO_{des}}\left<CO_{1}CO_{2}CO_{3}\right> + k_{CO_{ads}}\left<CO_{1}CO_{2}E_{3}\right> + k_{CO_{ads}}\left<CO_{1}E_{2}CO_{3}\right> + k_{CO_{ads}}\left<E_{1}CO_{2}CO_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 2. $\frac{d\left<CO_{1}CO_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $-\left(2k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}CO_{2}O_{3}\right>}{dt}=&-\left(2k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)\left<CO_{1}CO_{2}O_{3}\right> + k_{CO_{ads}}\left<CO_{1}E_{2}O_{3}\right> + k_{CO_{ads}}\left<E_{1}CO_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 3. $\frac{d\left<CO_{1}CO_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $-\left(k_{CO_{ads}} + 2k_{CO_{des}} + k_{CO_{dif}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}CO_{2}E_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}CO_{2}CO_{3}\right> + k_{COO_{e-r}}\left<CO_{1}CO_{2}O_{3}\right>-\left(k_{CO_{ads}} + 2k_{CO_{des}} + k_{CO_{dif}}\right)\left<CO_{1}CO_{2}E_{3}\right> + k_{CO_{dif}}\left<CO_{1}E_{2}CO_{3}\right> + k_{CO_{ads}}\left<CO_{1}E_{2}E_{3}\right> + k_{CO_{ads}}\left<E_{1}CO_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 4. $\frac{d\left<CO_{1}O_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $-\left(2k_{CO_{des}} + 2k_{COO_{l-h}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}O_{2}CO_{3}\right>}{dt}=&-\left(2k_{CO_{des}} + 2k_{COO_{l-h}} + k_{COO_{e-r}}\right)\left<CO_{1}O_{2}CO_{3}\right> + k_{CO_{ads}}\left<CO_{1}O_{2}E_{3}\right> + k_{CO_{ads}}\left<E_{1}O_{2}CO_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 5. $\frac{d\left<CO_{1}O_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $-\left(k_{O_{des}} + k_{CO_{des}} + k_{COO_{l-h}} + 2k_{COO_{e-r}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $k_{O_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}O_{2}O_{3}\right>}{dt}=&-\left(k_{O_{des}} + k_{CO_{des}} + k_{COO_{l-h}} + 2k_{COO_{e-r}}\right)\left<CO_{1}O_{2}O_{3}\right> + k_{O_{ads}}\left<CO_{1}E_{2}E_{3}\right> + k_{CO_{ads}}\left<E_{1}O_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 6. $\frac{d\left<CO_{1}O_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}O_{2}E_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}O_{2}CO_{3}\right> + k_{COO_{e-r}}\left<CO_{1}O_{2}O_{3}\right>-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)\left<CO_{1}O_{2}E_{3}\right> + k_{O_{dif}}\left<CO_{1}E_{2}O_{3}\right> + k_{CO_{ads}}\left<E_{1}O_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 7. $\frac{d\left<CO_{1}E_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $-\left(k_{CO_{ads}} + 2k_{CO_{des}} + 2k_{CO_{dif}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}E_{2}CO_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}CO_{2}CO_{3}\right> + k_{CO_{dif}}\left<CO_{1}CO_{2}E_{3}\right> + k_{COO_{e-r}}\left<CO_{1}O_{2}CO_{3}\right>-\left(k_{CO_{ads}} + 2k_{CO_{des}} + 2k_{CO_{dif}}\right)\left<CO_{1}E_{2}CO_{3}\right> + k_{CO_{ads}}\left<CO_{1}E_{2}E_{3}\right> + k_{CO_{dif}}\left<E_{1}CO_{2}CO_{3}\right> + k_{CO_{ads}}\left<E_{1}E_{2}CO_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 8. $\frac{d\left<CO_{1}E_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $k_{CO_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}E_{2}O_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}CO_{2}O_{3}\right> + k_{COO_{e-r}}\left<CO_{1}O_{2}O_{3}\right> + k_{O_{dif}}\left<CO_{1}O_{2}E_{3}\right>-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{e-r}}\right)\left<CO_{1}E_{2}O_{3}\right> + k_{CO_{dif}}\left<E_{1}CO_{2}O_{3}\right> + k_{CO_{ads}}\left<E_{1}E_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 9. $\frac{d\left<CO_{1}E_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $k_{O_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $-\left(k_{O_{ads}} + 2k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<CO_{1}E_{2}E_{3}\right>}{dt}=&k_{COO_{l-h}}\left<CO_{1}CO_{2}O_{3}\right> + k_{CO_{des}}\left<CO_{1}CO_{2}E_{3}\right> + k_{COO_{l-h}}\left<CO_{1}O_{2}CO_{3}\right> + k_{O_{des}}\left<CO_{1}O_{2}O_{3}\right> + k_{COO_{e-r}}\left<CO_{1}O_{2}E_{3}\right> + k_{CO_{des}}\left<CO_{1}E_{2}CO_{3}\right> + k_{COO_{e-r}}\left<CO_{1}E_{2}O_{3}\right>-\left(k_{O_{ads}} + 2k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}}\right)\left<CO_{1}E_{2}E_{3}\right> + k_{CO_{dif}}\left<E_{1}CO_{2}E_{3}\right> + k_{CO_{ads}}\left<E_{1}E_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 10. $\frac{d\left<O_{1}CO_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $-\left(2k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}CO_{2}CO_{3}\right>}{dt}=&-\left(2k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)\left<O_{1}CO_{2}CO_{3}\right> + k_{CO_{ads}}\left<O_{1}CO_{2}E_{3}\right> + k_{CO_{ads}}\left<O_{1}E_{2}CO_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 11. $\frac{d\left<O_{1}CO_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $-\left(k_{CO_{des}} + 2k_{COO_{l-h}} + 2k_{COO_{e-r}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}CO_{2}O_{3}\right>}{dt}=&-\left(k_{CO_{des}} + 2k_{COO_{l-h}} + 2k_{COO_{e-r}}\right)\left<O_{1}CO_{2}O_{3}\right> + k_{CO_{ads}}\left<O_{1}E_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 12. $\frac{d\left<O_{1}CO_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $-\left(k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $k_{CO_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}CO_{2}E_{3}\right>}{dt}=&k_{CO_{des}}\left<O_{1}CO_{2}CO_{3}\right> + k_{COO_{e-r}}\left<O_{1}CO_{2}O_{3}\right>-\left(k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)\left<O_{1}CO_{2}E_{3}\right> + k_{CO_{dif}}\left<O_{1}E_{2}CO_{3}\right> + k_{CO_{ads}}\left<O_{1}E_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 13. $\frac{d\left<O_{1}O_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $-\left(k_{O_{des}} + k_{CO_{des}} + k_{COO_{l-h}} + 2k_{COO_{e-r}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $k_{O_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}O_{2}CO_{3}\right>}{dt}=&-\left(k_{O_{des}} + k_{CO_{des}} + k_{COO_{l-h}} + 2k_{COO_{e-r}}\right)\left<O_{1}O_{2}CO_{3}\right> + k_{CO_{ads}}\left<O_{1}O_{2}E_{3}\right> + k_{O_{ads}}\left<E_{1}E_{2}CO_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 14. $\frac{d\left<O_{1}O_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $-\left(2k_{O_{des}} + 3k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $k_{O_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $k_{O_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}O_{2}O_{3}\right>}{dt}=&-\left(2k_{O_{des}} + 3k_{COO_{e-r}}\right)\left<O_{1}O_{2}O_{3}\right> + k_{O_{ads}}\left<O_{1}E_{2}E_{3}\right> + k_{O_{ads}}\left<E_{1}E_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 15. $\frac{d\left<O_{1}O_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $-\left(k_{O_{des}} + k_{O_{dif}} + k_{CO_{ads}} + 2k_{COO_{e-r}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $k_{O_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $k_{O_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}O_{2}E_{3}\right>}{dt}=&k_{CO_{des}}\left<O_{1}O_{2}CO_{3}\right> + k_{COO_{e-r}}\left<O_{1}O_{2}O_{3}\right>-\left(k_{O_{des}} + k_{O_{dif}} + k_{CO_{ads}} + 2k_{COO_{e-r}}\right)\left<O_{1}O_{2}E_{3}\right> + k_{O_{dif}}\left<O_{1}E_{2}O_{3}\right> + k_{O_{ads}}\left<E_{1}E_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 16. $\frac{d\left<O_{1}E_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $k_{CO_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}E_{2}CO_{3}\right>}{dt}=&k_{CO_{des}}\left<O_{1}CO_{2}CO_{3}\right> + k_{CO_{dif}}\left<O_{1}CO_{2}E_{3}\right> + k_{COO_{e-r}}\left<O_{1}O_{2}CO_{3}\right>-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{e-r}}\right)\left<O_{1}E_{2}CO_{3}\right> + k_{CO_{ads}}\left<O_{1}E_{2}E_{3}\right> + k_{O_{dif}}\left<E_{1}O_{2}CO_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 17. $\frac{d\left<O_{1}E_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $k_{O_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $-\left(2k_{O_{dif}} + k_{CO_{ads}} + 2k_{COO_{e-r}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $k_{O_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}E_{2}O_{3}\right>}{dt}=&k_{CO_{des}}\left<O_{1}CO_{2}O_{3}\right> + k_{COO_{e-r}}\left<O_{1}O_{2}O_{3}\right> + k_{O_{dif}}\left<O_{1}O_{2}E_{3}\right>-\left(2k_{O_{dif}} + k_{CO_{ads}} + 2k_{COO_{e-r}}\right)\left<O_{1}E_{2}O_{3}\right> + k_{O_{dif}}\left<E_{1}O_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 18. $\frac{d\left<O_{1}E_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $k_{COO_{l-h}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $k_{COO_{l-h}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $k_{O_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $-\left(k_{O_{ads}} + k_{O_{dif}} + 2k_{CO_{ads}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<O_{1}E_{2}E_{3}\right>}{dt}=&k_{COO_{l-h}}\left<O_{1}CO_{2}O_{3}\right> + k_{CO_{des}}\left<O_{1}CO_{2}E_{3}\right> + k_{COO_{l-h}}\left<O_{1}O_{2}CO_{3}\right> + k_{O_{des}}\left<O_{1}O_{2}O_{3}\right> + k_{COO_{e-r}}\left<O_{1}O_{2}E_{3}\right> + k_{CO_{des}}\left<O_{1}E_{2}CO_{3}\right> + k_{COO_{e-r}}\left<O_{1}E_{2}O_{3}\right>-\left(k_{O_{ads}} + k_{O_{dif}} + 2k_{CO_{ads}} + k_{COO_{e-r}}\right)\left<O_{1}E_{2}E_{3}\right> + k_{O_{dif}}\left<E_{1}O_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 19. $\frac{d\left<E_{1}CO_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $-\left(k_{CO_{ads}} + 2k_{CO_{des}} + k_{CO_{dif}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}CO_{2}CO_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}CO_{2}CO_{3}\right> + k_{CO_{dif}}\left<CO_{1}E_{2}CO_{3}\right> + k_{COO_{e-r}}\left<O_{1}CO_{2}CO_{3}\right>-\left(k_{CO_{ads}} + 2k_{CO_{des}} + k_{CO_{dif}}\right)\left<E_{1}CO_{2}CO_{3}\right> + k_{CO_{ads}}\left<E_{1}CO_{2}E_{3}\right> + k_{CO_{ads}}\left<E_{1}E_{2}CO_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 20. $\frac{d\left<E_{1}CO_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $k_{CO_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $-\left(k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}CO_{2}O_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}CO_{2}O_{3}\right> + k_{CO_{dif}}\left<CO_{1}E_{2}O_{3}\right> + k_{COO_{e-r}}\left<O_{1}CO_{2}O_{3}\right>-\left(k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)\left<E_{1}CO_{2}O_{3}\right> + k_{CO_{ads}}\left<E_{1}E_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 21. $\frac{d\left<E_{1}CO_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $-\left(2k_{CO_{ads}} + k_{CO_{des}} + 2k_{CO_{dif}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}CO_{2}E_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}CO_{2}E_{3}\right> + k_{CO_{dif}}\left<CO_{1}E_{2}E_{3}\right> + k_{COO_{e-r}}\left<O_{1}CO_{2}E_{3}\right> + k_{CO_{des}}\left<E_{1}CO_{2}CO_{3}\right> + k_{COO_{e-r}}\left<E_{1}CO_{2}O_{3}\right>-\left(2k_{CO_{ads}} + k_{CO_{des}} + 2k_{CO_{dif}}\right)\left<E_{1}CO_{2}E_{3}\right> + k_{CO_{dif}}\left<E_{1}E_{2}CO_{3}\right> + k_{CO_{ads}}\left<E_{1}E_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 22. $\frac{d\left<E_{1}O_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $k_{CO_{ads}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}O_{2}CO_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}O_{2}CO_{3}\right> + k_{COO_{e-r}}\left<O_{1}O_{2}CO_{3}\right> + k_{O_{dif}}\left<O_{1}E_{2}CO_{3}\right>-\left(k_{O_{dif}} + k_{CO_{ads}} + k_{CO_{des}} + k_{COO_{l-h}} + k_{COO_{e-r}}\right)\left<E_{1}O_{2}CO_{3}\right> + k_{CO_{ads}}\left<E_{1}O_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 23. $\frac{d\left<E_{1}O_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $k_{O_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $-\left(k_{O_{des}} + k_{O_{dif}} + k_{CO_{ads}} + 2k_{COO_{e-r}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $k_{O_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}O_{2}O_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}O_{2}O_{3}\right> + k_{COO_{e-r}}\left<O_{1}O_{2}O_{3}\right> + k_{O_{dif}}\left<O_{1}E_{2}O_{3}\right>-\left(k_{O_{des}} + k_{O_{dif}} + k_{CO_{ads}} + 2k_{COO_{e-r}}\right)\left<E_{1}O_{2}O_{3}\right> + k_{O_{ads}}\left<E_{1}E_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 24. $\frac{d\left<E_{1}O_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $-\left(2k_{O_{dif}} + 2k_{CO_{ads}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}O_{2}E_{3}\right>}{dt}=&k_{CO_{des}}\left<CO_{1}O_{2}E_{3}\right> + k_{COO_{e-r}}\left<O_{1}O_{2}E_{3}\right> + k_{O_{dif}}\left<O_{1}E_{2}E_{3}\right> + k_{CO_{des}}\left<E_{1}O_{2}CO_{3}\right> + k_{COO_{e-r}}\left<E_{1}O_{2}O_{3}\right>-\left(2k_{O_{dif}} + 2k_{CO_{ads}} + k_{COO_{e-r}}\right)\left<E_{1}O_{2}E_{3}\right> + k_{O_{dif}}\left<E_{1}E_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 25. $\frac{d\left<E_{1}E_{2}CO_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $k_{O_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $k_{CO_{dif}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $-\left(k_{O_{ads}} + 2k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $k_{CO_{ads}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}E_{2}CO_{3}\right>}{dt}=&k_{COO_{l-h}}\left<CO_{1}O_{2}CO_{3}\right> + k_{CO_{des}}\left<CO_{1}E_{2}CO_{3}\right> + k_{COO_{l-h}}\left<O_{1}CO_{2}CO_{3}\right> + k_{O_{des}}\left<O_{1}O_{2}CO_{3}\right> + k_{COO_{e-r}}\left<O_{1}E_{2}CO_{3}\right> + k_{CO_{des}}\left<E_{1}CO_{2}CO_{3}\right> + k_{CO_{dif}}\left<E_{1}CO_{2}E_{3}\right> + k_{COO_{e-r}}\left<E_{1}O_{2}CO_{3}\right>-\left(k_{O_{ads}} + 2k_{CO_{ads}} + k_{CO_{des}} + k_{CO_{dif}}\right)\left<E_{1}E_{2}CO_{3}\right> + k_{CO_{ads}}\left<E_{1}E_{2}E_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 26. $\frac{d\left<E_{1}E_{2}O_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $k_{COO_{l-h}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $k_{COO_{l-h}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $k_{O_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $k_{CO_{des}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $k_{COO_{e-r}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $k_{O_{dif}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $-\left(k_{O_{ads}} + k_{O_{dif}} + 2k_{CO_{ads}} + k_{COO_{e-r}}\right)$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}E_{2}O_{3}\right>}{dt}=&k_{COO_{l-h}}\left<CO_{1}O_{2}O_{3}\right> + k_{CO_{des}}\left<CO_{1}E_{2}O_{3}\right> + k_{COO_{l-h}}\left<O_{1}CO_{2}O_{3}\right> + k_{O_{des}}\left<O_{1}O_{2}O_{3}\right> + k_{COO_{e-r}}\left<O_{1}E_{2}O_{3}\right> + k_{CO_{des}}\left<E_{1}CO_{2}O_{3}\right> + k_{COO_{e-r}}\left<E_{1}O_{2}O_{3}\right> + k_{O_{dif}}\left<E_{1}O_{2}E_{3}\right>-\left(k_{O_{ads}} + k_{O_{dif}} + 2k_{CO_{ads}} + k_{COO_{e-r}}\right)\left<E_{1}E_{2}O_{3}\right>
# 	\end{align}
# $$

# %% [markdown]
# 27. $\frac{d\left<E_{1}E_{2}E_{3}\right>}{dt}$:
#
# <table style="background-color: white; width: 100%; text-align: left">
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			1. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			2. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			3. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			4. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			5. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			6. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			7. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			8. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			9. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			10. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			11. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			12. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			13. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			14. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			15. $k_{O_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			16. $0$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			17. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			18. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			19. $0$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			20. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			21. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			22. $k_{COO_{l-h}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			23. $k_{O_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			24. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			25. $k_{CO_{des}}$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			26. $k_{COO_{e-r}}$
# 		</td>
# 	</tr>
# 	<tr>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 			27. $-\left(2k_{O_{ads}} + 3k_{CO_{ads}}\right)$
# 		</td>
# 		<td style="background-color: white; width: 100%; text-align: left">
# 		</td>
# 	</tr>
# </table>
#
# ***
#
# $$
# 	\begin{align}
# 		\frac{d\left<E_{1}E_{2}E_{3}\right>}{dt}=&k_{COO_{l-h}}\left<CO_{1}O_{2}E_{3}\right> + k_{CO_{des}}\left<CO_{1}E_{2}E_{3}\right> + k_{COO_{l-h}}\left<O_{1}CO_{2}E_{3}\right> + k_{O_{des}}\left<O_{1}O_{2}E_{3}\right> + k_{COO_{e-r}}\left<O_{1}E_{2}E_{3}\right> + k_{COO_{l-h}}\left<E_{1}CO_{2}O_{3}\right> + k_{CO_{des}}\left<E_{1}CO_{2}E_{3}\right> + k_{COO_{l-h}}\left<E_{1}O_{2}CO_{3}\right> + k_{O_{des}}\left<E_{1}O_{2}O_{3}\right> + k_{COO_{e-r}}\left<E_{1}O_{2}E_{3}\right> + k_{CO_{des}}\left<E_{1}E_{2}CO_{3}\right> + k_{COO_{e-r}}\left<E_{1}E_{2}O_{3}\right>-\left(2k_{O_{ads}} + 3k_{CO_{ads}}\right)\left<E_{1}E_{2}E_{3}\right>
# 	\end{align}
# $$

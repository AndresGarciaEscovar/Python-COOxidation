# %% [markdown]
# # $CO$ Oxidation in Ruthenium (111)

# %% [markdown]
# Import the code where the mathematica generator is.

# %%
from mathematica_generator import EquationGenerator
import itertools

# %%
# Create the equation generator.
tmp = EquationGenerator()

tmp.get_nth_order_equations(order=2, print_equations=False)
# Out:
# Rejected:
# (('CO', 1), ('CO', 2))
# (('CO', 1), ('CO', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('CO', 2), ('CO', 3))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('CO', 1), ('O', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('CO', 2), ('O', 3))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('CO', 1), ('E', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('CO', 2), ('E', 3))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('O', 1), ('CO', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('O', 2), ('CO', 3))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('O', 1), ('O', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('O', 2), ('O', 3))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('O', 1), ('E', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('O', 2), ('E', 3))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('E', 1), ('CO', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('E', 2), ('CO', 3))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# (('E', 1), ('O', 2))
#
# Accepted:
# (('CO', 1), ('CO', 2))
# ...

# %%
list_items = [1, 2, 3]

print(list(itertools.combinations(list_items, 2)))
# Out:
# [(1, 2), (1, 3), (2, 3)]
